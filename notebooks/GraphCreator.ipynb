# %%
from os.path import join, abspath, dirname

import sys
sys.path.insert(0, abspath(join(dirname("."), '..')))

from modules.helpers.graphs_utis import *
import pickle

# %%
csvs_folder = '/media/xander/HDD/Repos/data/graphs/csv'
output_folder = '/media/xander/HDD/Repos/data/graphs/'

# %%
# Save graphs as .gpickle files (fast, NetworkX native)
graphs = build_graphs_from_folder(
    input_folder=csvs_folder,
    output_folder=output_folder,
    has_header=False,
    pattern="*.csv"
)

# %%
# Usage
generate_experimental_seeds(output_folder, pct=0.10, seed=2026)

# %%
graph_data = []
graph_path = Path(output_folder)

for pkl_file in graph_path.glob("*.pkl"):
    base_name = pkl_file.stem.replace('.pkl', '')  # or adjust pattern
    seeds_file = join(output_folder, f"{base_name}.seeds.txt")  # From image pattern
    
    if not Path(seeds_file).exists():
        print(f"No seeds file for {pkl_file}, checked for: {seeds_file}")
        continue
    
    # Load graph from pickle
    with open(pkl_file, 'rb') as f:
        G = pickle.load(f)  
    # Load seeds
    seeds = load_seeds(seeds_file)
    
    # Get degrees for seeds
    degrees = [(seed, G.degree(seed)) for seed in seeds if seed in G]
    to_print = []
    
    for item in degrees:
        seed, deg = item
        to_print.append(f"{seed}")
        graph_data.append((base_name, seed, deg))
    print(f"{base_name.replace('_edges', '')}:", ','.join(to_print))
    
    degrees = [d for _, d in G.degree()]  # list of all node degrees

    min_deg = min(degrees)
    max_deg = max(degrees)
    avg_deg = stats.mean(degrees)  # or sum(degrees) / len(degrees)
    med_deg = stats.median(degrees)  # Handles even/odd node counts

    graph_data.append((base_name, "min_deg", min_deg))
    graph_data.append((base_name, "max_deg", max_deg))
    graph_data.append((base_name, "avg_deg", avg_deg))
    graph_data.append((base_name, "med_deg", med_deg))

graph_df = pd.DataFrame(data=graph_data, columns=["graph_name","node","degree"])

# %%
graph_df.to_csv('seed_benchmarks.csv',index=False)
