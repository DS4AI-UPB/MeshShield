# %%
# %pip install scikit-learn Pandas NumPy joblib NetworkX Spacy
# %pip install gputil psutil tqdm
# PyTorch is required, get it for your specific CUDA version from https://pytorch.org/get-started/locally/
# %pip install TorchText Transformers Simpletransformers humanize
# %pip install GitPython

# %%
# Linux verions of pytorch with cuda
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
